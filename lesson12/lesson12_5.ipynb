# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50, 5))
df1 = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index = range(1,51))
df1
# Out:
#     國文  英文   數學   地理  歷史
# 1   53  82   91   71  56
# 2   64  92   91   53  85
# 3   87  53   93   82  71
# 4   72  65   54   61  98
# 5   58  96   80   74  81
# 6   93  55   55   82  86
# 7   53  83   63  100  73
# 8   89  93   98   95  80
# 9   73  99   74   93  53
# 10  64  57   76   84  91
# 11  94  62   60   98  97
# 12  80  52   88   90  60
# 13  68  75   93   68  81
# 14  51  72   74   76  72
# 15  53  54   67   78  63
# 16  77  87   80   70  69
# 17  80  83   94   87  95
# 18  69  58   70   99  51
# 19  90  52   68   93  69
# 20  95  80   65   66  67
# 21  83  99   51   64  95
# 22  72  73   94   97  90
# 23  80  84   91   81  50
# 24  99  68   92   59  55
# 25  57  83   52   57  77
# 26  78  85   86   54  64
# 27  61  84   71   56  99
# 28  84  86   65   84  85
# 29  62  63   50   86  82
# 30  54  68   84   70  97
# 31  92  78   89   50  89
# 32  65  84   71   50  59
# 33  82  90   72   90  77
# 34  87  80   58   65  76
# 35  83  88   77   87  83
# 36  88  96   80   57  77
# ...

# %% [markdown]
# ## index.name
# ## columns.name

# %%
df1.index.name = '學號'
df1.columns.name = "科目"

# %%
df1.loc[1].sum()
# Out:
# np.int64(353)

# %%
sum = df1.sum(axis=1)  #numpy.sum()

average = sum / 5

# %%
df1['總分'] = sum
df1['平均'] = average
df1
# Out:
# 科目  國文  英文   數學   地理  歷史   總分    平均
# 學號
# 1   53  82   91   71  56  353  70.6
# 2   64  92   91   53  85  385  77.0
# 3   87  53   93   82  71  386  77.2
# 4   72  65   54   61  98  350  70.0
# 5   58  96   80   74  81  389  77.8
# 6   93  55   55   82  86  371  74.2
# 7   53  83   63  100  73  372  74.4
# 8   89  93   98   95  80  455  91.0
# 9   73  99   74   93  53  392  78.4
# 10  64  57   76   84  91  372  74.4
# 11  94  62   60   98  97  411  82.2
# 12  80  52   88   90  60  370  74.0
# 13  68  75   93   68  81  385  77.0
# 14  51  72   74   76  72  345  69.0
# 15  53  54   67   78  63  315  63.0
# 16  77  87   80   70  69  383  76.6
# 17  80  83   94   87  95  439  87.8
# 18  69  58   70   99  51  347  69.4
# 19  90  52   68   93  69  372  74.4
# 20  95  80   65   66  67  373  74.6
# 21  83  99   51   64  95  392  78.4
# 22  72  73   94   97  90  426  85.2
# 23  80  84   91   81  50  386  77.2
# 24  99  68   92   59  55  373  74.6
# 25  57  83   52   57  77  326  65.2
# ...

# %% [markdown]
# ## 搜尋

# %%
#英文不及格的
english_series = df1['英文'] < 60
df1[english_series]
# Out:
# 科目  國文  英文   數學  地理  歷史   總分    平均
# 學號
# 3   87  53   93  82  71  386  77.2
# 6   93  55   55  82  86  371  74.2
# 10  64  57   76  84  91  372  74.4
# 12  80  52   88  90  60  370  74.0
# 15  53  54   67  78  63  315  63.0
# 18  69  58   70  99  51  347  69.4
# 19  90  52   68  93  69  372  74.4
# 49  87  58  100  94  52  391  78.2
