# %% [markdown]
# ## pypi

# %%
import requests    #終端機pip install requests
from requests import Response
url ='https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate desc&format=CSV'
r:Response = requests.get(url)
if r.ok:
    print('下載成功')
# Out:
# 下載成功

# %%
from io import StringIO
import csv

data:str = r.text  #文字檔
file = StringIO(data)    #StringIO(data) 會把傳入的'字串' data 當作'檔案內容'，並返回一個可以讀取和寫入的類似檔案物件。
dictReader = csv.DictReader(file,fieldnames=['sitename','county','aqi','status','pm2.5','datacreationdate','longitude'],restkey='不要')
next(dictReader)
datas:list[dict] = list(dictReader)
for site in datas:
    del site['不要']
    print(site)
# Out:
# {'sitename': '屏東(枋山)', 'county': '屏東縣', 'aqi': '37', 'status': '', 'pm2.5': '良好', 'datacreationdate': '3.1', 'longitude': '0.27'}
# {'sitename': '宜蘭（頭城）', 'county': '宜蘭縣', 'aqi': '24', 'status': '', 'pm2.5': '良好', 'datacreationdate': '0', 'longitude': '0.22'}
# {'sitename': '新北(樹林)', 'county': '新北市', 'aqi': '33', 'status': '', 'pm2.5': '良好', 'datacreationdate': '0.9', 'longitude': '0.39'}
# {'sitename': '屏東（琉球）', 'county': '屏東縣', 'aqi': '67', 'status': '細懸浮微粒', 'pm2.5': '普通', 'datacreationdate': '3.5', 'longitude': '0.45'}
# {'sitename': '臺南（麻豆）', 'county': '臺南市', 'aqi': '20', 'status': '', 'pm2.5': '良好', 'datacreationdate': '1.5', 'longitude': '0.27'}
# {'sitename': '高雄（湖內）', 'county': '高雄市', 'aqi': '38', 'status': '', 'pm2.5': '良好', 'datacreationdate': '1.7', 'longitude': '0.39'}
# {'sitename': '彰化（員林）', 'county': '彰化縣', 'aqi': '24', 'status': '', 'pm2.5': '良好', 'datacreationdate': '2.2', 'longitude': '0.33'}
# ...

# %%
with open('aqi.csv',mode='w',encoding='utf-8',newline='') as file:
    dict_writer = csv.DictWriter(file,fieldnames=['sitename','county','aqi','status','pm2.5','datacreationdate','longitude'])
    dict_writer.writeheader()
    dict_writer.writerows(datas)
